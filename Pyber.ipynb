# %% [markdown]
# ## Unit 5 | Assignment - The Power of Plots
#
# ## Background
#
# What good is data without a good plot to tell the story?
#
# So, let's take what you've learned about Python Matplotlib and apply it to some real-world situations. For this assignment, you'll need to complete **1 of 2** Data Challenges. As always, it's your choice which you complete. _Perhaps_, choose the one most relevant to your future career.
#
# ## Option 1: Pyber
#
# ![Ride](Images/Ride.png)
#
# The ride sharing bonanza continues! Seeing the success of notable players like Uber and Lyft, you've decided to join a fledgling ride sharing company of your own. In your latest capacity, you'll be acting as Chief Data Strategist for the company. In this role, you'll be expected to offer data-backed guidance on new opportunities for market differentiation.
#
# You've since been given access to the company's complete recordset of rides. This contains information about every active driver and historic ride, including details like city, driver count, individual fares, and city type.
#
# Your objective is to build a [Bubble Plot](https://en.wikipedia.org/wiki/Bubble_chart) that showcases the relationship between four key variables:
#
# * Average Fare ($) Per City
# * Total Number of Rides Per City
# * Total Number of Drivers Per City
# * City Type (Urban, Suburban, Rural)
#
# In addition, you will be expected to produce the following three pie charts:
#
# * % of Total Fares by City Type
# * % of Total Rides by City Type
# * % of Total Drivers by City Type
#
# As final considerations:
#
# * You must use the Pandas Library and the Jupyter Notebook.
# * You must use the Matplotlib and Seaborn libraries.
# * You must include a written description of three observable trends based on the data.
# * You must use proper labeling of your plots, including aspects like: Plot Titles, Axes Labels, Legend Labels, Wedge Percentages, and Wedge Labels.
# * Remember when making your plots to consider aesthetics!
#   * You must stick to the Pyber color scheme (Gold, Light Sky Blue, and Light Coral) in producing your plot and pie charts.
#   * When making your Bubble Plot, experiment with effects like `alpha`, `edgecolor`, and `linewidths`.
#   * When making your Pie Chart, experiment with effects like `shadow`, `startangle`, and `explosion`.
# * You must include an exported markdown version of your Notebook called  `README.md` in your GitHub repository.
# * See [Example Solution](Pyber/Pyber_Example.pdf) for a reference on expected format.

# %% [markdown]
# PYBER TREND ANALYSIS
#
# •	There are more drivers in the urban cities than in suburban and rural cities.
#
# •	Rural areas have less drivers and higher cost per ride. This may be due to less demand and perhaps longer ride times between destinations.
#
# •	Although 77% of drivers are in urban areas, they only make up 62% of average fares. The average fare per ride in urban cities is lower than suburban and rural cities.

# %%
# Dependencies
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn
seaborn.set()
colors=["gold", "light sky blue", "coral"]
palette=seaborn.xkcd_palette(colors)
seaborn.set_palette(palette)
seaborn.set_style({"axes.facecolor":"darkgray"})

# %%
#Import and read the CSV file
# reading city data
city_data_df=pd.read_csv("city_data.csv")
city_data_df.head()
# Out:
#              city  driver_count   type
# 0      Kelseyland            63  Urban
# 1      Nguyenbury             8  Urban
# 2    East Douglas            12  Urban
# 3   West Dawnfurt            34  Urban
# 4  Rodriguezburgh            52  Urban

# %%
# reading ride data
ride_data_df=pd.read_csv("ride_data.csv")
ride_data_df.head()
# Out:
#           city                 date   fare        ride_id
# 0     Sarabury  2016-01-16 13:49:27  38.35  5403689035038
# 1    South Roy  2016-01-02 18:42:34  17.49  4036272335942
# 2  Wiseborough  2016-01-21 17:35:29  44.18  3645042422587
# 3  Spencertown  2016-07-31 14:53:22   6.87  2242596575892
# 4   Nguyenbury  2016-07-09 04:42:44   6.28  1543057793673

# %%
merge_df= pd.merge(ride_data_df, city_data_df,how="left", on="city")
merge_df.head()
# Out:
#           city                 date   fare        ride_id  driver_count   type
# 0     Sarabury  2016-01-16 13:49:27  38.35  5403689035038            46  Urban
# 1    South Roy  2016-01-02 18:42:34  17.49  4036272335942            35  Urban
# 2  Wiseborough  2016-01-21 17:35:29  44.18  3645042422587            55  Urban
# 3  Spencertown  2016-07-31 14:53:22   6.87  2242596575892            68  Urban
# 4   Nguyenbury  2016-07-09 04:42:44   6.28  1543057793673             8  Urban

# %%
grouped_df=merge_df.groupby("city").mean()
grouped_df
# Out:
#                            fare       ride_id  driver_count
# city
# Alvarezhaven          23.928710  5.351586e+12          21.0
# Alyssaberg            20.609615  3.536678e+12          67.0
# Anitamouth            37.315556  4.195870e+12          16.0
# Antoniomouth          23.625000  5.086800e+12          21.0
# Aprilchester          21.981579  4.574788e+12          49.0
# Arnoldview            25.106452  5.021952e+12          41.0
# Campbellport          33.711333  5.805424e+12          26.0
# Carrollbury           36.606000  4.274615e+12           4.0
# Carrollfort           25.395517  4.759008e+12          55.0
# Clarkstad             31.051667  6.682745e+12          21.0
# Conwaymouth           34.591818  4.391649e+12          18.0
# Davidtown             22.978095  5.850005e+12          73.0
# Davistown             21.497200  4.361977e+12          25.0
# East Cherylfurt       31.416154  3.981187e+12           9.0
# East Douglas          26.169091  4.732315e+12          12.0
# ...

# %%
bubble_df= merge_df.join(grouped_df, on="city", rsuffix="_average")
#drop columns ride_id average and driver count average
bubble_df=bubble_df.drop(["ride_id_average", "driver_count_average"],axis=1)
bubble_df.head()
# Out:
#           city                 date   fare        ride_id  driver_count  \
# 0     Sarabury  2016-01-16 13:49:27  38.35  5403689035038            46
# 1    South Roy  2016-01-02 18:42:34  17.49  4036272335942            35
# 2  Wiseborough  2016-01-21 17:35:29  44.18  3645042422587            55
# 3  Spencertown  2016-07-31 14:53:22   6.87  2242596575892            68
# 4   Nguyenbury  2016-07-09 04:42:44   6.28  1543057793673             8
#
#     type  fare_average
# 0  Urban     23.490000
# 1  Urban     26.031364
# 2  Urban     22.676842
# 3  Urban     23.681154
# 4  Urban     25.899615

# %%
ride_counts=pd.DataFrame(bubble_df["city"].value_counts())
ride_counts.columns=["Number of Rides"]
ride_counts.head()
# Out:
#                Number of Rides
# Port James                  64
# Swansonbury                 34
# Port Johnstad               34
# South Louis                 32
# Williamshire                31

# %%
bubble_df= bubble_df.join(ride_counts, on="city")
bubble_df.head()
# Out:
#           city                 date   fare        ride_id  driver_count  \
# 0     Sarabury  2016-01-16 13:49:27  38.35  5403689035038            46
# 1    South Roy  2016-01-02 18:42:34  17.49  4036272335942            35
# 2  Wiseborough  2016-01-21 17:35:29  44.18  3645042422587            55
# 3  Spencertown  2016-07-31 14:53:22   6.87  2242596575892            68
# 4   Nguyenbury  2016-07-09 04:42:44   6.28  1543057793673             8
#
#     type  fare_average  Number of Rides
# 0  Urban     23.490000               27
# 1  Urban     26.031364               22
# 2  Urban     22.676842               19
# 3  Urban     23.681154               26
# 4  Urban     25.899615               26

# %%
urban_cities=bubble_df[bubble_df["type"]=="Urban"]
rural_cities=bubble_df[bubble_df["type"]=="Rural"]
suburban_cities=bubble_df[bubble_df["type"]=="Suburban"]
urban_cities.head()
# Out:
#           city                 date   fare        ride_id  driver_count  \
# 0     Sarabury  2016-01-16 13:49:27  38.35  5403689035038            46
# 1    South Roy  2016-01-02 18:42:34  17.49  4036272335942            35
# 2  Wiseborough  2016-01-21 17:35:29  44.18  3645042422587            55
# 3  Spencertown  2016-07-31 14:53:22   6.87  2242596575892            68
# 4   Nguyenbury  2016-07-09 04:42:44   6.28  1543057793673             8
#
#     type  fare_average  Number of Rides
# 0  Urban     23.490000               27
# 1  Urban     26.031364               22
# 2  Urban     22.676842               19
# 3  Urban     23.681154               26
# 4  Urban     25.899615               26

# %%
plt.scatter(urban_cities["Number of Rides"],urban_cities["fare_average"],s=urban_cities["driver_count"]*10,edgecolors="black",alpha=.75,label="urban")
plt.scatter(rural_cities["Number of Rides"],rural_cities["fare_average"],s=rural_cities["driver_count"]*10,edgecolors="black", alpha=.75,label="rural")
plt.scatter(suburban_cities["Number of Rides"],suburban_cities["fare_average"],s=suburban_cities["driver_count"]*10,edgecolors="black", alpha=.75,label="suburban")
plt.xlabel("Number of Rides")
plt.ylabel("Average Fare ($)")
plt.title("Ride Share")
plt.legend()
plt.show()

# %%
total_fares=bubble_df["fare"].sum()
urban_fares=urban_cities["fare"].sum()
suburban_fares=suburban_cities["fare"].sum()
rural_fares=rural_cities["fare"].sum()
total_fares
# Out:
# 64669.12

# %% [markdown]
# PERCENTAGE OF FARES BY CITY TYPE

# %%
urban_fares_percent=urban_fares/total_fares
suburban_fares_percent=suburban_fares/total_fares
rural_fares_percent=rural_fares/total_fares

# %%
explode=[0.3,0,0]
plt.pie([urban_fares_percent, suburban_fares_percent, rural_fares_percent],explode=explode,shadow=True,startangle=90,labels=["Urban", "Suburban","Rural"],autopct='%.2f%%')
plt.title("Percentage of Fares by City Type")
plt.legend()
plt.axis("equal")
plt.show()

# %% [markdown]
# PERCENTAGE OF DRIVERS BY CITY TYPE

# %%
#Number of Drivers
number_drivers=city_data_df.groupby("type").sum()
number_drivers
# Out:
#           driver_count
# type
# Rural              104
# Suburban           638
# Urban             2607

# %%
total_drivers=number_drivers["driver_count"].sum()
total_drivers
# Out:
# 3349

# %%
percent_drivers=number_drivers/total_drivers
percent_drivers
# Out:
#           driver_count
# type
# Rural         0.031054
# Suburban      0.190505
# Urban         0.778441

# %%
explode=[0.0,0,0.1]
plt.pie(percent_drivers, startangle=90,explode=explode,shadow=True,labels=percent_drivers.index,autopct='%.2f%%',pctdistance=0.9)
plt.title("Percentage of Drivers Per City Type")
plt.legend()
plt.axis("equal")
plt.show()

# %% [markdown]
# TOTAL RIDES PERCENTAGE PER CITY TYPE

# %%
rides=bubble_df.groupby("type").count()["ride_id"]
rides
# Out:
# type
# Rural        125
# Suburban     657
# Urban       1625
# Name: ride_id, dtype: int64

# %%
percent_rides=rides/bubble_df["ride_id"].count()
percent_rides
# Out:
# type
# Rural       0.051932
# Suburban    0.272954
# Urban       0.675114
# Name: ride_id, dtype: float64

# %%
explode=[0.0,0,0.1]
plt.pie(percent_rides, startangle=90,explode=explode,shadow=True,labels=percent_rides.index,autopct='%.2f%%',pctdistance=0.9)
plt.title("Percentage of Rides per City Type")
plt.legend()
plt.axis("equal")
plt.show()
